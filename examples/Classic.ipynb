# %% [markdown]
# # Example game: Classic variant
# We will play through the first few years of the game `http://webdiplomacy.net/board.php?gameID=300732` from the 2020 Masters Tournament on webDiplomacy.

# %% [markdown]
# ## Setup
#
# Only run this cell once.

# %%
import glob, os
os.chdir('../')  # Set working directory to main folder.

import adjudicator.game as gm

# %%
game = gm.Game('Classic')
game.start()
game.display('season')
game.show()
# Out:
# Diplomacy in Spring 1901.

# %%
game.display('season')
game.order(['F Sev - BLA', 'A War - Gal', 'F StP - GoB', 'A Mos - Ukr'])
game.order(['A Con - Bul', 'F Ank - BLA', 'A Smy - Con'])
game.order(['A Bud - Ser', 'F Tri - Alb', 'A Vie - Bud'])
game.order(['A Mun - Ruh', 'A Ber - Kie', 'F Kie - Hol'])
game.order(['A Ven H', 'F Nap - ION', 'A Rom - Apu'])
game.order(['A Mar - Spa', 'A Par - Bur', 'F Bre - ENG'])
game.order(['F Lon - NTH', 'A Lvp - Edi', 'F Edi - NWG'])
game.adjudicate()
game.show()
# Out:
# Diplomacy in Spring 1901.

# %%
game.order(['A Gal - Bud', 'F GoB - Swe', 'A Ukr - Rum', 'F Sev S Ukr - Rum'])
game.order(['A Bul H', 'F Ank - BLA', 'A Con - Bul'])
game.order(['F Alb - Gre', 'A Bud - Vie', 'A Ser S Alb - Gre'])
game.order(['A Ruh - Bel', 'A Kie - Den', 'F Hol S Ruh -  Bel'])
game.order(['A Ven H', 'A Apu - Tun via C', 'F ION C Apu - Tun'])
game.order(['A Spa - Por', 'A Bur - Bel', 'F ENG - Lon'])
game.order(['A Edi - Lon via C', 'F NWG - Nwy', 'F NTH C Edi - Lon'])
game.adjudicate()
game.show()

# %%
game.display('season')
game.order(['Russia 1 B A War', 'Russia 2 B A Mos', 'Russia 3 B F StP (n)'])
game.order(['Turkey 1 B F Smy'])
game.order(['Austria 1 B A Tri'])
game.order(['Germany 1 B A Mun', 'Germany 2 B A Ber', 'Germany 3 B A Kie'])
game.order(['Italy 1 B F Nap'])
game.order(['France 1 B F Bre'])
game.order(['England 1 B F Lon'])
game.adjudicate()
game.show()
# Out:
# Builds in 1901.

# %%
game.order(['F StP - Nwy', 'A War - Sil', 'A Mos - StP', 'A Bud - Tri',
           'A Sev S Rum H', 'F Swe S StP - Nwy', 'A Rum S Bul - Ser'])
game.order(['F Smy - AEG', 'A Bul - Ser', 'A Con - Bul', 'F BLA S Con - Bul'])
game.order(['A Tri - Bud', 'F Gre - AEG', 'A Ser S Con - Rum', 'A Ser S Con - Rum', 'A Vie S Tri - Bud'])
game.order(['A Mun - Bur', 'A Ber - Kie', 'A Kie - Ruh', 'F Hol - NTH', 'A Bel S Mun - Bur', 'A Den S Nwy - Swe'])
game.order(['F Nap - TYS', 'F ION - Tun', 'A Tun - NAf', 'A Ven - Pie'])
game.order(['F Bre - ENG', 'A Por - Spa', 'A Bur - Bel', 'F ENG - IRI'])
game.order(['F Lon - ENG', 'F NTH - Nwy', 'A Edi - Yor', 'F Nwy - Swe'])
game.adjudicate()
game.show()

# %%
game.order(['Swe - BAL', 'Bud - Gal'])
game.order(['Ser - Tri'])
game.order(['Bur - Mar'])
game.display('orders')
game.adjudicate()
game.show()
# Out:
# The Army in Serbia retreats to Trieste.
# The Army in Burgundy retreats to Marseilles.
# The Fleet in Sweden retreats to Baltic Sea.
# The Army in Budapest retreats to Galicia.
